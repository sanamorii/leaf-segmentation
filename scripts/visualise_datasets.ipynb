# %%
import torch
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import colors

from PIL import Image
import albumentations as A

# %%
def show_mask_visual(mask):
    plt.figure(figsize=(10, 10))
    decoded = Image.open(mask).convert("L")
    n_classes = len(np.unique(np.array(decoded)))
    cmap = plt.cm.get_cmap('tab20', n_classes)
    norm = colors.BoundaryNorm(boundaries=np.arange(-0.5, n_classes + 0.5, 1), ncolors=n_classes)
    im = plt.imshow(decoded, cmap=cmap, norm=norm)
    plt.axis('off')

    cbar = plt.colorbar(im, ticks=range(n_classes))
    cbar.set_label('Classes')

show_mask_visual("../data/semantic/pd_sdxl/bean#1/mask/0153_train.png")
# Out:
# /tmp/ipykernel_2180050/2655688973.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab20', n_classes)

# %%
# resolution shape - always 2d (hopefully)
m = np.array(Image.open("63.png"))
print(m.shape)
print(len(m.shape))
# Out:
# (512, 512)
# 2

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np


def visualize_mask_classes(mask_path):
    mask = np.array(Image.open(mask_path).convert("L"))
    if mask is None:
        raise ValueError("Mask could not be loaded. Check the file path.")

    classes = np.unique(mask)
    print("Classes found in mask:", classes)
    num_classes = len(classes)
    cols = 4
    rows = int(np.ceil(num_classes / cols))

    plt.figure(figsize=(4 * cols, 4 * rows))

    for i, cls in enumerate(classes):
        binary = (mask == cls).astype(np.uint8) * 255

        plt.subplot(rows, cols, i + 1)
        plt.imshow(binary, cmap="gray")
        plt.title(f"Class {cls}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()


# Example usage
pth = Path("../data/semantic/pd_sdxl/bean#1/mask")
for i, file in enumerate(pth.iterdir()):
    if len(file.stem.split("_")) == 1:
        visualize_mask_classes(str(file))

    if i == 10:
        break
    # print(len(file.stem.split("_")))
# Out:
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]
# Classes found in mask: [0 1 2 3]

# %%
import cv2
import numpy as np
from pathlib import Path

def fix_mask_classes(input_path, output_path, wrong_id=4, correct_id=3):
    mask = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError("Could not load mask. Check the path.")

    print("Classes before:", np.unique(mask))
    mask_fixed = np.where(mask == wrong_id, correct_id, mask).astype(np.uint8)
    cv2.imwrite(output_path, mask_fixed)
    print("Classes after:", np.unique(mask_fixed))

    print(f"Fixed mask saved to {output_path}")

dataset = Path("/home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask")
masks = dataset.glob("*.png")

for mask in masks:
    fix_mask_classes(mask, mask)
# Out:
# Classes before: [0 1]
# Classes after: [0 1]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0198_train.png
# Classes before: [0 1 4]
# Classes after: [0 1 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0063_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0103_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0144_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0102_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0192_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0101_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0049_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0129_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0100_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0096_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0216_eval.png
# Classes before: [0 1 4]
# Classes after: [0 1 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0067_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0106_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0104_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0105_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0089_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0172_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0191_train.png
# Classes before: [0 1 2]
# Classes after: [0 1 2]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0154_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0123_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0190_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0155_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0156_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0193_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0150_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0195_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0184_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0126_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0151_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0194_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0179_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0127_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0124_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0196_train.png
# Classes before: [0 1 2]
# Classes after: [0 1 2]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0153_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0152_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0125_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0092_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0137_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0141_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0093_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0140_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0185_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0090_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0135_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0136_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0186_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0143_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0134_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0091_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0187_train.png
# Classes before: [0 1 4]
# Classes after: [0 1 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0022_train.png
# Classes before: [0 1 2 3 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0142_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0180_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0145_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0133_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0181_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0097_train.png
# Classes before: [0 1 2]
# Classes after: [0 1 2]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0132_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0147_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0182_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0051_train.png
# Classes before: [0 1]
# Classes after: [0 1]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0131_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0094_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0146_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0183_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0095_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0130_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0148_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0128_eval.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0149_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0099_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0098_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0201_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0189_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0188_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0058_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0138_train.png
# Classes before: [0 1 2 4]
# Classes after: [0 1 2 3]
# Fixed mask saved to /home/psyqc1/leaf-segmentation/data/bean_real_semantic/mask/0139_train.png
